# %%
import json
from pymongo import MongoClient
from collections import Counter

# %%
mongo = MongoClient('172.17.0.1', 27017)
db = mongo['bad-vis']
vislabels = db['vislabels']

# %%
visLabels = [l for l in vislabels.find()]

# %%
labels = {l for labels in visLabels for l in labels['labels']}
labelCnts = Counter([l for labels in visLabels for l in labels['labels']])

# %%
labels
# Out:
# {'data:accumulated',
#  'data:bitmap',
#  'data:categorical',
#  'data:cyclic',
#  'data:flow',
#  'data:geospatial',
#  'data:indexvalue',
#  'data:multivariate',
#  'data:network',
#  'data:ordinal',
#  'data:percentage',
#  'data:probability',
#  'data:quantitative',
#  'data:ranking',
#  'data:sequential',
#  'data:set',
#  'data:text',
#  'data:timeseries',
#  'data:tree',
#  'fault:3d',
#  'fault:animation',
#  'fault:area',
#  'fault:axis',
#  'fault:axis:double',
#  'fault:axis:flipped',
#  'fault:axis:label',
#  'fault:axis:missing',
#  'fault:axis:truncated',
#  'fault:betteralternative',
#  'fault:binning',
#  'fault:cannotaddup',
#  'fault:chartjunk',
#  'fault:cluttering',
#  'fault:color',
#  'fault:color:over12',
#  'fault:confirmationbias',
#  'fault:connection',
#  'fault:data',
#  'fault:data:missingvalues',
#  'fault:data:prediction',
#  'fault:data:questionable',
#  'fault:data:redundant',
#  'fault:data:selective',
#  'fault:description',
#  'fault:encoding',
# ...

# %%
labelCnts.most_common(20)
# Out:
# [('data:categorical', 356),
#  ('data:quantitative', 233),
#  ('data:percentage', 192),
#  ('form:barchart', 163),
#  ('data:timeseries', 102),
#  ('form:linechart', 93),
#  ('form:piechart', 80),
#  ('fault:color', 63),
#  ('data:geospatial', 62),
#  ('fault:percentage:encoding', 61),
#  ('fault:scale:inconsistent', 54),
#  ('media:printed', 51),
#  ('flag:needreview', 50),
#  ('flag:notbad', 48),
#  ('fault:label', 41),
#  ('fault:description', 38),
#  ('form:choropleth', 37),
#  ('fault:legend', 33),
#  ('fault:axis:label', 33),
#  ('fault:3d', 30)]

# %%
labelOptions = [
    {
        'tag': 'form:barchart',
        'category': 'form',
        'subcategory': 'bar',
        'name': 'Bar Chart',
        'description': 'Data encoded with length. Chart lies when length disproportional to the encoded value.'
    },
    {
        'tag': 'form:linechart',
        'category': 'form',
        'subcategory': 'line',
        'name': 'Line Chart',
        'description': 'Can be seen as a scatterplot with connected dots. Most widely used with time series data. Chart lies when the context is hidden, changes being magnified or diminished.'
    },
    {
        'tag': 'form:scatterplot',
        'category': 'form',
        'subcategory': 'point',
        'name': 'Scatter Plot',
        'description': 'Direct encoding of attributes into X and Y axes. Mostly use to find correlation. Chart lies when an agenda of a trend or correlation is imposed.'
    },
    {
        'tag': 'form:dotplot',
        'category': 'form',
        'subcategory': 'bar',
        'name': 'Dot Plot',
        'description': 'Similar to bar charts. Data encoded with number of dots, but compared as length since the dots are aligned. Mostly used for observing distribution.'
    },
    {
        'tag': 'form:barcodechart',
        'category': 'form',
        'subcategory': 'point',
        'name': 'Barcode Chart',
        'description': 'Can be seen as a 1-D scatter plot. Most commonly used to show frequency distribution.'
    },
    {
        'tag': 'form:areachart',
        'category': 'form',
        'subcategory': 'area',
        'name': 'Area Chart',
        'description': 'Can be seen as a line chart with color filled area under the curve. Most widely used to convey the accumulated volumn. Chart lies when the area is distorted by truncating the Y-axis.'
    },
    {
        'tag': 'form:histogram',
        'category': 'form',
        'subcategory': 'bar',
        'name': 'Histogram',
        'description': 'Similar to bar chart, but breaking down the continuous X-axis into bins in order to observe the distribution. Chart lies when the bin size is uneven or being manipulated.'
    },
    {
        'tag': 'form:nodelink',
        'category': 'form',
        'subcategory': 'line',
        'name': 'Node-Link Diagram',
        'description': 'Dots are connected to show their relationships. Most common diagram for network data. The X-axis or Y-axis positions of nodes has no meaning.'
    },
    {
        'tag': 'form:parallelcoor',
        'category': 'form',
        'subcategory': 'line',
        'name': 'Parallel Coordinates',
        'description': 'Multiple Y-axes in one chart, each line is an instance in data and each Y-axis is the attribute values. Most widely used in multi-dimensional data.'
    },
    {
        'tag': 'form:radarchart',
        'category': 'form',
        'subcategory': 'line',
        'name': 'Radar Chart',
        'description': 'Can be seen as a parallel coordinates plot wrapped in a circle or regular polygon. The area enclosed by the lines conveys the sum of attribute values. Also common in comparison to spot the skyline (see "skyline problem").'
    },
    {
        'tag': 'form:bubblechart',
        'category': 'form',
        'subcategory': 'point',
        'name': '',
        'description': 'Similar to scatter plot, but with size encoding on each circle. Most common issue is occlusion, also inherits the issues of size encoding.'
    },
    {
        'tag': 'form:boxplot',
        'category': 'form',
        'subcategory': 'box',
        'name': 'Box Plot',
        'description': 'A box depicts the statistics summary of the underlying data. The whiskers show the maximum/minimum and box shows 25th quartile, median and 75th quartile.'
    },
    {
        'tag': 'form:violinplot',
        'category': 'form',
        'subcategory': 'box',
        'name': 'Violin Plot',
        'description': 'Similar to box plot. In addition, the width encodes the density distribution of the underlying data. Skewed distribution can be observed.'
    },
    {
        'tag': 'form:dumbbellplot',
        'category': 'form',
        'subcategory': 'point',
        'name': 'Dumbbell Plot',
        'description': ''
    },
    {
        'tag': 'form:piechart',
        'category': 'form',
        'subcategory': 'pie',
        'name': 'Pie Chart',
        'description': ''
    },
    {
        'tag': 'form:donutchart',
        'category': 'form',
        'subcategory': 'pie',
        'name': 'Donut Chart',
        'description': ''
    },
    {
        'tag': 'form:pyramid',
        'category': 'form',
        'subcategory': 'shape',
        'name': 'Pyramid',
        'description': ''
    },
    {
        'tag': 'form:venn',
        'category': 'form',
        'subcategory': 'shape',
        'name': 'Venn Diagram',
        'description': ''
    },
    {
        'tag': 'form:choropleth',
        'category': 'form',
        'subcategory': 'map',
        'name': 'Choropleth',
        'description': ''
    },
    {
        'tag': 'form:flowmap',
        'category': 'form',
        'subcategory': 'map',
        'name': 'Flow Map',
        'description': ''
    },
    {
        'tag': 'form:map',
        'category': 'form',
        'subcategory': 'map',
        'name': 'Map',
        'description': ''
    },
    {
        'tag': 'form:chernoffface',
        'category': 'form',
        'subcategory': 'other',
        'name': 'Chernoff Face',
        'description': ''
    },
    {
        'tag': 'form:streamgraph',
        'category': 'form',
        'subcategory': 'area',
        'name': 'Stream Graph',
        'description': ''
    },
    {
        'tag': 'form:pictogram',
        'category': 'form',
        'subcategory': 'bar',
        'name': 'Pictogram',
        'description': ''
    },
    {
        'tag': 'form:guagechart',
        'category': 'form',
        'subcategory': 'other',
        'name': 'Guage Chart',
        'description': ''
    },
    {
        'tag': 'form:sankeydiagram',
        'category': 'form',
        'subcategory': 'line',
        'name': 'Sankey Diagram',
        'description': ''
    },
    {
        'tag': 'form:sunbrust',
        'category': 'form',
        'subcategory': 'other',
        'name': 'Sunbrust Diagram',
        'description': ''
    },
    {
        'tag': 'form:voronoi',
        'category': 'form',
        'subcategory': 'shape',
        'name': 'Voronoi Diagram',
        'description': ''
    },
    {
        'tag': 'form:table',
        'category': 'form',
        'subcategory': 'table',
        'name': 'Table',
        'description': ''
    },
    {
        'tag': 'form:heatmap',
        'category': 'form',
        'subcategory': 'Table',
        'name': 'Heatmap',
        'description': ''
    },
    {
        'tag': 'form:treemap',
        'category': 'form',
        'subcategory': 'area',
        'name': 'Treemap',
        'description': ''
    },
    {
        'tag': 'form:quadrant',
        'category': 'form',
        'subcategory': 'other',
        'name': 'Quadrant',
        'description': ''
    },
    {
        'tag': 'form:unknown',
        'category': 'form',
        'subcategory': 'other',
        'name': 'Unclassified',
        'description': ''
    },

    {
        'tag': 'data:categorical',
        'category': 'data',
        'subcategory': 'attribute',
        'name': 'Categorical',
        'description': ''
    },
    {
        'tag': 'data:quantitative',
        'category': 'data',
        'subcategory': 'attribute',
        'name': 'Quantitative',
        'description': ''
    },
    {
        'tag': 'data:sequential',
        'category': 'data',
        'subcategory': 'attribute',
        'name': 'Sequential',
        'description': ''
    },
    {
        'tag': 'data:multivariate',
        'category': 'data',
        'subcategory': 'attribute',
        'name': 'Multivariate',
        'description': ''
    },
    {
        'tag': 'data:indexvalue',
        'category': 'data',
        'subcategory': 'derived',
        'name': 'Index Value',
        'description': ''
    },
    {
        'tag': 'data:accumulated',
        'category': 'data',
        'subcategory': 'derived',
        'name': 'Accumulated',
        'description': ''
    },
    {
        'tag': 'data:percentage',
        'category': 'data',
        'subcategory': 'derived',
        'name': 'Percentage',
        'description': ''
    },
    {
        'tag': 'data:probability',
        'category': 'data',
        'subcategory': 'derived',
        'name': 'Probability',
        'description': ''
    },
    {
        'tag': 'data:ordinal',
        'category': 'data',
        'subcategory': 'ordered',
        'name': 'Ordinal',
        'description': 'Ordinal values are values that represent the order between items. These values can be used comparatively but not arithmetically, like alphabetical order.'
    },
    {
        'tag': 'data:ranking',
        'category': 'data',
        'subcategory': 'ordered',
        'name': 'Ranking',
        'description': ''
    },
    {
        'tag': 'data:timeseries',
        'category': 'data',
        'subcategory': 'series',
        'name': 'Time Series',
        'description': 'Time series data concern changes over time, most commonly with a fixed interval. The time values can be absolute (Nov 23, 2012) or relative (Day 0, Day 1, ...).'
    },
    {
        'tag': 'data:cyclic',
        'category': 'data',
        'subcategory': 'series',
        'name': 'Cyclic',
        'description': 'Cyclical data are series of data with repeated sequences that can be aligned. Examples are running laps, seasonal and monthly cycle.'
    },
    {
        'tag': 'data:geospatial',
        'category': 'data',
        'subcategory': 'position',
        'name': 'Geospatial',
        'description': ''
    },
    {
        'tag': 'data:flow',
        'category': 'data',
        'subcategory': 'position',
        'name': 'Flow',
        'description': ''
    },
    {
        'tag': 'data:bitmap',
        'category': 'data',
        'subcategory': 'position',
        'name': 'Bitmap',
        'description': ''
    },
    {
        'tag': 'data:network',
        'category': 'data',
        'subcategory': 'network',
        'name': 'Network',
        'description': ''
    },
    {
        'tag': 'data:tree',
        'category': 'data',
        'subcategory': 'network',
        'name': 'Tree',
        'description': ''
    },
    {
        'tag': 'data:set',
        'category': 'data',
        'subcategory': 'other',
        'name': 'Set',
        'description': ''
    },
    {
        'tag': 'data:text',
        'category': 'data',
        'subcategory': 'other',
        'name': 'Text',
        'description': ''
    },

    {
        'tag': 'layout:circular',
        'category': 'layout',
        'subcategory': '',
        'name': 'Circular',
        'description': ''
    },
    {
        'tag': 'layout:infographics',
        'category': 'layout',
        'subcategory': '',
        'name': 'Infographics',
        'description': ''
    },
    {
        'tag': 'layout:stacked',
        'category': 'layout',
        'subcategory': '',
        'name': 'Stacked',
        'description': ''
    },
    {
        'tag': 'layout:map',
        'category': 'layout',
        'subcategory': '',
        'name': 'Map',
        'description': ''
    },
    {
        'tag': 'layout:juxtaposition',
        'category': 'layout',
        'subcategory': '',
        'name': 'Juxtaposition',
        'description': ''
    },
    {
        'tag': 'layout:overlay',
        'category': 'layout',
        'subcategory': '',
        'name': 'Overlay',
        'description': ''
    },
    {
        'tag': 'layout:mixed',
        'category': 'layout',
        'subcategory': '',
        'name': 'Mixed',
        'description': ''
    },

    {
        'tag': 'metaphor:pictograph',
        'category': 'metaphor',
        'subcategory': '',
        'name': 'Pictograph',
        'description': ''
    },
    {
        'tag': 'metaphor:periodictable',
        'category': 'metaphor',
        'subcategory': '',
        'name': 'Periodictable',
        'description': ''
    },
    {
        'tag': 'metaphor:gear',
        'category': 'metaphor',
        'subcategory': '',
        'name': 'Gearion',
        'description': ''
    },
    {
        'tag': 'metaphor:clock',
        'category': 'metaphor',
        'subcategory': '',
        'name': 'Clock',
        'description': ''
    },

    {
        'tag': 'media:inreallife',
        'category': 'media',
        'subcategory': '',
        'name': 'Inreallife',
        'description': ''
    },
    {
        'tag': 'media:printed',
        'category': 'media',
        'subcategory': '',
        'name': 'Printed',
        'description': ''
    },
    {
        'tag': 'media:handdrawn',
        'category': 'media',
        'subcategory': '',
        'name': 'Handdrawn',
        'description': ''
    },
    {
        'tag': 'media:tv',
        'category': 'media',
        'subcategory': '',
        'name': 'Tv',
        'description': ''
    },
    {
        'tag': 'media:ads',
        'category': 'media',
        'subcategory': '',
        'name': 'Ads',
        'description': ''
    },
    {
        'tag': 'media:news',
        'category': 'media',
        'subcategory': '',
        'name': 'News',
        'description': ''
    },
    {
        'tag': 'media:NSFW',
        'category': 'media',
        'subcategory': '',
        'name': 'Nsfw',
        'description': ''
    },

    {
        'tag': 'fault:percentage',
        'category': 'fault',
        'subcategory: '',
        'name': 'percentage',
        'description': ''
    },
    {
        'tag': 'fault:percentage:sum',
        'category': 'fault',
        'subcategory: '',
        'name': 'percentage:sum',
        'description': ''
    },
    {
        'tag': 'fault:percentage:encoding',
        'category': 'fault',
        'subcategory: '',
        'name': 'percentage:encoding',
        'description': ''
    },
    {
        'tag': 'fault:percentage:wholepart',
        'category': 'fault',
        'subcategory: '',
        'name': 'percentage:wholepart',
        'description': ''
    },
    {
        'tag': 'fault:label',
        'category': 'fault',
        'subcategory: '',
        'name': 'label',
        'description': ''
    },
    {
        'tag': 'fault:description',
        'category': 'fault',
        'subcategory: '',
        'name': 'description',
        'description': ''
    },
    {
        'tag': 'fault:axis',
        'category': 'fault',
        'subcategory: '',
        'name': 'axis',
        'description': ''
    },
    {
        'tag': 'fault:axis:label',
        'category': 'fault',
        'subcategory: '',
        'name': 'axis:label',
        'description': ''
    },
    {
        'tag': 'fault:axis:flipped',
        'category': 'fault',
        'subcategory: '',
        'name': 'axis:flipped',
        'description': ''
    },
    {
        'tag': 'fault:axis:truncated',
        'category': 'fault',
        'subcategory: '',
        'name': 'axis:truncated',
        'description': ''
    },
    {
        'tag': 'fault:axis:missing',
        'category': 'fault',
        'subcategory: '',
        'name': 'axis:missing',
        'description': ''
    },
    {
        'tag': 'fault:axis:double',
        'category': 'fault',
        'subcategory: '',
        'name': 'axis:double',
        'description': ''
    },
    {
        'tag': 'fault:legend',
        'category': 'fault',
        'subcategory: '',
        'name': 'legend',
        'description': ''
    },
    {
        'tag': 'fault:color',
        'category': 'fault',
        'subcategory: '',
        'name': 'color',
        'description': ''
    },
    {
        'tag': 'fault:color:over12',
        'category': 'fault',
        'subcategory: '',
        'name': 'color:over12',
        'description': ''
    },
    {
        'tag': 'fault:scale',
        'category': 'fault',
        'subcategory: '',
        'name': 'scale',
        'description': ''
    },
    {
        'tag': 'fault:scale:log',
        'category': 'fault',
        'subcategory: '',
        'name': 'scale:log',
        'description': ''
    },
    {
        'tag': 'fault:scale:inconsistent',
        'category': 'fault',
        'subcategory: '',
        'name': 'scale:inconsistent',
        'description': ''
    },
    {
        'tag': 'fault:binning',
        'category': 'fault',
        'subcategory: '',
        'name': 'binning',
        'description': ''
    },
    {
        'tag': 'fault:area',
        'category': 'fault',
        'subcategory: '',
        'name': 'area',
        'description': ''
    },
    {
        'tag': 'fault:picto:distortion',
        'category': 'fault',
        'subcategory: '',
        'name': 'picto:distortion',
        'description': ''
    },
    {
        'tag': 'fault:picto:area',
        'category': 'fault',
        'subcategory: '',
        'name': 'picto:area',
        'description': ''
    },
    {
        'tag': 'fault:position',
        'category': 'fault',
        'subcategory: '',
        'name': 'position',
        'description': ''
    },
    {
        'tag': 'fault:itemorder',
        'category': 'fault',
        'subcategory: '',
        'name': 'itemorder',
        'description': ''
    },
    {
        'tag': 'fault:connection',
        'category': 'fault',
        'subcategory: '',
        'name': 'connection',
        'description': ''
    },
    {
        'tag': 'fault:3d',
        'category': 'fault',
        'subcategory: '',
        'name': '3d',
        'description': ''
    },
    {
        'tag': 'fault:animation',
        'category': 'fault',
        'subcategory: '',
        'name': 'animation',
        'description': ''
    },
    {
        'tag': 'fault:cluttering',
        'category': 'fault',
        'subcategory: '',
        'name': 'cluttering',
        'description': ''
    },
    {
        'tag': 'fault:occulusion',
        'category': 'fault',
        'subcategory: '',
        'name': 'occulusion',
        'description': ''
    },
    {
        'tag': 'fault:data',
        'category': 'fault',
        'subcategory: '',
        'name': 'data',
        'description': ''
    },
    {
        'tag': 'fault:data:selective',
        'category': 'fault',
        'subcategory: '',
        'name': 'data:selective',
        'description': ''
    },
    {
        'tag': 'fault:data:questionable',
        'category': 'fault',
        'subcategory: '',
        'name': 'data:questionable',
        'description': ''
    },
    {
        'tag': 'fault:data:missingvalues',
        'category': 'fault',
        'subcategory: '',
        'name': 'data:missingvalues',
        'description': ''
    },
    {
        'tag': 'fault:data:redundant',
        'category': 'fault',
        'subcategory: '',
        'name': 'data:redundant',
        'description': ''
    },
    {
        'tag': 'fault:data:prediction',
        'category': 'fault',
        'subcategory: '',
        'name': 'data:prediction',
        'description': ''
    },
    {
        'tag': 'fault:index:comparison',
        'category': 'fault',
        'subcategory: '',
        'name': 'index:comparison',
        'description': ''
    },
    {
        'tag': 'fault:parody',
        'category': 'fault',
        'subcategory: '',
        'name': 'parody',
        'description': ''
    },
    {
        'tag': 'fault:faultylogic',
        'category': 'fault',
        'subcategory: '',
        'name': 'faultylogic',
        'description': ''
    },
    {
        'tag': 'fault:missingcontext',
        'category': 'fault',
        'subcategory: '',
        'name': 'missingcontext',
        'description': ''
    },
    {
        'tag': 'fault:confirmationbias',
        'category': 'fault',
        'subcategory: '',
        'name': 'confirmationbias',
        'description': ''
    },
    {
        'tag': 'fault:chartjunk',
        'category': 'fault',
        'subcategory: '',
        'name': 'chartjunk',
        'description': ''
    },
    {
        'tag': 'fault:betteralternative',
        'category': 'fault',
        'subcategory: '',
        'name': 'betteralternative',
        'description': ''
    },
    {
        'tag': 'fault:faultystatistics',
        'category': 'fault',
        'subcategory: '',
        'name': 'faultystatistics',
        'description': ''
    },
    {
        'tag': 'fault:invalidcomparison',
        'category': 'fault',
        'subcategory: '',
        'name': 'invalidcomparison',
        'description': ''
    },
    {
        'tag': 'fault:map:population',
        'category': 'fault',
        'subcategory: '',
        'name': 'map:population',
        'description': ''
    },
    {
        'tag': 'fault:invalidencoding',
        'category': 'fault',
        'subcategory: '',
        'name': 'invalidencoding',
        'description': ''
    },
    {
        'tag': 'fault:unreadable',
        'category': 'fault',
        'subcategory: '',
        'name': 'unreadable',
        'description': ''
    },
    {
        'tag': 'fault:visuallyawful',
        'category': 'fault',
        'subcategory: '',
        'name': 'visuallyawful',
        'description': ''
    },
    {
        'tag': 'fault:encoding',
        'category': 'fault',
        'subcategory: '',
        'name': 'encoding',
        'description': ''
    },
    {
        'tag': 'fault:cannotaddup',
        'category': 'fault',
        'subcategory: '',
        'name': 'cannotaddup',
        'description': ''
    },
    {
        'tag': 'fault:legibility',
        'category': 'fault',
        'subcategory: '',
        'name': 'legibility',
        'description': ''
    },
]

{
    'form': [
        'barchart', 'linechart', 'scatterplot', 'dotplot', 'barcodechart', 'areachart', 'histogram',
        'nodelink', 'radarchart', 'bubblechart', 'dumbbellplot',
        'piechart', 'donutchart',
        'pyramid', 'venn', 'choropleth', 'flowmap', 'map', 'chernoffface',
        'table', 'heatmap', 'treemap', 'quadrant',
        'boxplot', 'violinplot', 'parallelcoor', 'streamgraph',
        'pictogram', 'guagechart', 'sankeydiagram', 'chorddiagram', 'sunbrust', 'voronoi',
        'unknown'
    ],
    'data': [
        'categorical', 'quantitative', 'indexvalue', 'accumulated',
        'percentage', 'probability',
        'ordinal', 'ranking', 'sequential',
        'timeseries', 'cyclic',
        'geospatial', 'flow',
        'network', 'tree',
        'set', 'bitmap',
        'text', 'multivariate',
    ],
#     'encoding': [
#         'position', 'position(unaligned)', 'length', 'area', 'tilt',
#         'curvature', 'region', 'motion', 'shape',
#         'depth', 'volume',
#         'luminance', 'saturation', 'hue'
#     ],
#     'mark': [
#         'line', 'rectangle', 'point'
#     ],
    'layout': [
        'circular', 'infographics', 'stacked', 'map', 'juxtaposition', 'overlay', 'mixed'
    ],
    'metaphor': [
        'pictograph', 'periodictable', 'gear', 'clock'
    ],
    'media': [
        'inreallife', 'printed', 'handdrawn', 'tv', 'ads', 'news', 'NSFW'
    ],
    'fault': [
        'percentage', 'percentage:sum', 'percentage:encoding', 'percentage:wholepart',
        'label', 'description',
        'axis', 'axis:label', 'axis:flipped', 'axis:truncated', "axis:missing", 'axis:double', # axis:dual
        'legend',
        'color', 'color:over12',
        'scale', 'scale:log', 'scale:inconsistent', 'binning',
        'area',
        'picto:distortion', 'picto:area',
        'position', 'itemorder',
        'connection',
        '3d', 'animation',
        'cluttering', 'occulusion',
        'data', 'data:selective', 'data:questionable', 'data:missingvalues', 'data:redundant', 'data:prediction',
        'index:comparison', # index:crossbasiscomparison
        'parody', 'faultylogic', 'missingcontext',
        'confirmationbias', 'chartjunk', 'betteralternative',
        'faultystatistics', 'invalidcomparison',
        'map:population', 'invalidencoding',
        'unreadable', 'visuallyawful',
        'encoding', 'cannotaddup', 'legibility'
    ],
    'flag': [
        'needreview', 'invalid', 'notbad', 'starred'
    ]
}

# %%
labelOptions = {
    'form': [
        'barchart', 'linechart', 'scatterplot', 'dotplot', 'barcodechart', 'areachart', 'histogram',
        'nodelink', 'radarchart', 'bubblechart', 'dumbbellplot',
        'piechart', 'donutchart',
        'pyramid', 'venn', 'choropleth', 'flowmap', 'map', 'chernoffface',
        'table', 'heatmap', 'treemap', 'quadrant',
        'boxplot', 'violinplot', 'parallelcoor', 'streamgraph',
        'pictogram', 'guagechart', 'sankeydiagram', 'chorddiagram', 'sunbrust', 'voronoi',
        'unknown'
    ],
    'data': [
        'categorical', 'quantitative', 'indexvalue', 'accumulated',
        'percentage', 'probability',
        'ordinal', 'ranking', 'sequential',
        'timeseries', 'cyclic',
        'geospatial', 'flow',
        'network', 'tree',
        'set', 'bitmap',
        'text', 'multivariate',
    ],
#     'encoding': [
#         'position', 'position(unaligned)', 'length', 'area', 'tilt',
#         'curvature', 'region', 'motion', 'shape',
#         'depth', 'volume',
#         'luminance', 'saturation', 'hue'
#     ],
#     'mark': [
#         'line', 'rectangle', 'point'
#     ],
    'layout': [
        'circular', 'infographics', 'stacked', 'map', 'juxtaposition', 'overlay', 'mixed'
    ],
    'metaphor': [
        'pictograph', 'periodictable', 'gear', 'clock'
    ],
    'media': [
        'inreallife', 'printed', 'handdrawn', 'tv', 'ads', 'news', 'NSFW'
    ],
    'fault': [
        'percentage', 'percentage:sum', 'percentage:encoding', 'percentage:wholepart',
        'label', 'description',
        'axis', 'axis:label', 'axis:flipped', 'axis:truncated', "axis:missing", 'axis:double', # axis:dual
        'legend',
        'color', 'color:over12',
        'scale', 'scale:log', 'scale:inconsistent', 'binning',
        'area',
        'picto:distortion', 'picto:area',
        'position', 'itemorder',
        'connection',
        '3d', 'animation',
        'cluttering', 'occulusion',
        'data', 'data:selective', 'data:questionable', 'data:missingvalues', 'data:redundant', 'data:prediction',
        'index:comparison', # index:crossbasiscomparison
        'parody', 'faultylogic', 'missingcontext',
        'confirmationbias', 'chartjunk', 'betteralternative',
        'faultystatistics', 'invalidcomparison',
        'map:population', 'invalidencoding',
        'unreadable', 'visuallyawful',
        'encoding', 'cannotaddup', 'legibility'
    ],
    'flag': [
        'needreview', 'invalid', 'notbad', 'starred'
    ]
}

# %%
json.dump(labelOptions, open('labelOptions.json', 'w'), separators=(',', ':'))
