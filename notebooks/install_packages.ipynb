# %%
# !apt update && apt install -y libmagic-dev libxrender1 libxtst6 libxi6
# !pip install altair vega_datasets
# !pip install ffmpy
# !pip install ImageHash
# !pip install imgur-downloader
# !pip install imutils
# !pip install opencv-python
# !pip install pafy
# !pip install praw
# !pip install pydash
# !pip install pymongo
# !pip install python-magic
# !pip install pytumblr
# !pip install requests-cache
# !pip install requests_toolbelt
# !pip install simplejson
# !pip install termcolor
# !pip install tweepy
# !pip install youtube-dl
# !python3 -m pip install pyppeteer

# sequence dependent
# !pip install webp
# !pip uninstall -y Pillow
# !pip install Pillow
# !pip install piexif
# Out:
# Collecting altair
#   Using cached altair-4.1.0-py3-none-any.whl (727 kB)
# Collecting vega_datasets
#   Downloading vega_datasets-0.9.0-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 18.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from altair) (1.19.5)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.8/site-packages (from altair) (0.3)
# Requirement already satisfied: pandas>=0.18 in /opt/conda/lib/python3.8/site-packages (from altair) (1.2.1)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.8/site-packages (from altair) (0.11.1)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.8/site-packages (from altair) (3.2.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from altair) (2.11.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.18->altair) (2020.5)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.18->altair) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from jinja2->altair) (1.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema->altair) (20.3.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from jsonschema->altair) (49.6.0.post20210108)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema->altair) (0.17.3)
# Installing collected packages: vega-datasets, altair
# Successfully installed altair-4.1.0 vega-datasets-0.9.0
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4709 sha256=0cce1b4b75ad4fc79a78ea6d9f2aaae374aa20d646e8ddc7329ae2fd41144759
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ff/5b/59/913b443e7369dc04b61f607a746b6f7d83fb65e2e19fcc958d
# Successfully built ffmpy
# Installing collected packages: ffmpy
# Successfully installed ffmpy-0.3.0
# Collecting ImageHash
#   Using cached ImageHash-4.2.0-py2.py3-none-any.whl (295 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from ImageHash) (1.15.0)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.8/site-packages (from ImageHash) (8.1.0)
# Requirement already satisfied: PyWavelets in /opt/conda/lib/python3.8/site-packages (from ImageHash) (1.1.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from ImageHash) (1.19.5)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.8/site-packages (from ImageHash) (1.6.0)
# Installing collected packages: ImageHash
# Successfully installed ImageHash-4.2.0
# Collecting imgur-downloader
#   Using cached imgur_downloader-0.2.2-py3-none-any.whl
# Requirement already satisfied: click in /opt/conda/lib/python3.8/site-packages (from imgur-downloader) (7.1.2)
# Installing collected packages: imgur-downloader
# Successfully installed imgur-downloader-0.2.2
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py) ... done
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25860 sha256=b1593ba9f8e70f14b9c6d6a3640bfe01f3e07c0aed679ff0e1327d68f0e99777
#   Stored in directory: /home/jovyan/.cache/pip/wheels/59/1b/52/0dea905f8278d5514dc4d0be5e251967f8681670cadd3dca89
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4
# Collecting opencv-python
#   Downloading opencv_python-4.5.1.48-cp38-cp38-manylinux2014_x86_64.whl (50.4 MB)
#      |████████████████████████████████| 50.4 MB 11.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.8/site-packages (from opencv-python) (1.19.5)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.5.1.48
# Collecting pafy
#   Using cached pafy-0.5.5-py2.py3-none-any.whl (35 kB)
# Installing collected packages: pafy
# Successfully installed pafy-0.5.5
# Collecting praw
#   Downloading praw-7.1.4-py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 24.0 MB/s eta 0:00:01
# Collecting update-checker>=0.18
#   Using cached update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Collecting prawcore<2.0,>=1.5.0
#   Using cached prawcore-1.5.0-py3-none-any.whl (15 kB)
# Collecting websocket-client>=0.54.0
#   Using cached websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Requirement already satisfied: requests<3.0,>=2.6.0 in /opt/conda/lib/python3.8/site-packages (from prawcore<2.0,>=1.5.0->praw) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests<3.0,>=2.6.0->prawcore<2.0,>=1.5.0->praw) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3.0,>=2.6.0->prawcore<2.0,>=1.5.0->praw) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3.0,>=2.6.0->prawcore<2.0,>=1.5.0->praw) (1.26.3)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0,>=2.6.0->prawcore<2.0,>=1.5.0->praw) (2.10)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from websocket-client>=0.54.0->praw) (1.15.0)
# Installing collected packages: websocket-client, update-checker, prawcore, praw
# Successfully installed praw-7.1.4 prawcore-1.5.0 update-checker-0.18.0 websocket-client-0.57.0
# Collecting pydash
#   Downloading pydash-4.9.2-py2.py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 5.7 MB/s  eta 0:00:01
# Installing collected packages: pydash
# Successfully installed pydash-4.9.2
# Collecting pymongo
#   Downloading pymongo-3.11.3-cp38-cp38-manylinux2014_x86_64.whl (531 kB)
#      |████████████████████████████████| 531 kB 24.8 MB/s eta 0:00:01
# Installing collected packages: pymongo
# Successfully installed pymongo-3.11.3
# Collecting python-magic
#   Using cached python_magic-0.4.18-py2.py3-none-any.whl (8.6 kB)
# Installing collected packages: python-magic
# Successfully installed python-magic-0.4.18
# Collecting pytumblr
#   Using cached PyTumblr-0.1.0-py2.py3-none-any.whl (15 kB)
# Collecting requests-oauthlib
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting future
#   Using cached future-0.18.2-py3-none-any.whl
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from requests-oauthlib->pytumblr) (3.0.1)
# Requirement already satisfied: requests>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from requests-oauthlib->pytumblr) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib->pytumblr) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib->pytumblr) (1.26.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib->pytumblr) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib->pytumblr) (2.10)
# Installing collected packages: requests-oauthlib, future, pytumblr
# Successfully installed future-0.18.2 pytumblr-0.1.0 requests-oauthlib-1.3.0
# Collecting requests-cache
#   Using cached requests_cache-0.5.2-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: requests>=1.1.0 in /opt/conda/lib/python3.8/site-packages (from requests-cache) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=1.1.0->requests-cache) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=1.1.0->requests-cache) (1.26.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=1.1.0->requests-cache) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=1.1.0->requests-cache) (2.10)
# Installing collected packages: requests-cache
# Successfully installed requests-cache-0.5.2
# Collecting requests_toolbelt
#   Using cached requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
# Requirement already satisfied: requests<3.0.0,>=2.0.1 in /opt/conda/lib/python3.8/site-packages (from requests_toolbelt) (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.1->requests_toolbelt) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.1->requests_toolbelt) (1.26.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.1->requests_toolbelt) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.1->requests_toolbelt) (2.10)
# Installing collected packages: requests-toolbelt
# Successfully installed requests-toolbelt-0.9.1
# Collecting simplejson
#   Using cached simplejson-3.17.2-cp38-cp38-manylinux2010_x86_64.whl (137 kB)
# Installing collected packages: simplejson
# Successfully installed simplejson-3.17.2
# Collecting termcolor
#   Using cached termcolor-1.1.0-py3-none-any.whl
# Installing collected packages: termcolor
# Successfully installed termcolor-1.1.0
# Collecting tweepy
#   Downloading tweepy-3.10.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: requests[socks]>=2.11.1 in /opt/conda/lib/python3.8/site-packages (from tweepy) (2.25.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.8/site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.8/site-packages (from tweepy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (1.26.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Installing collected packages: tweepy
# Successfully installed tweepy-3.10.0
# Collecting youtube-dl
#   Downloading youtube_dl-2021.2.4.1-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 23.9 MB/s eta 0:00:01
# Installing collected packages: youtube-dl
# Successfully installed youtube-dl-2021.2.4.1
# Collecting pyppeteer
#   Downloading pyppeteer-0.2.5-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 8.4 MB/s  eta 0:00:01
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /opt/conda/lib/python3.8/site-packages (from pyppeteer) (1.4.4)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /opt/conda/lib/python3.8/site-packages (from pyppeteer) (1.26.3)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.1.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /opt/conda/lib/python3.8/site-packages (from pyppeteer) (4.56.0)
# Collecting websockets<9.0,>=8.1
#   Using cached websockets-8.1-cp38-cp38-manylinux2010_x86_64.whl (78 kB)
# Installing collected packages: websockets, pyee, pyppeteer
# Successfully installed pyee-8.1.0 pyppeteer-0.2.5 websockets-8.1
# Collecting webp
#   Using cached webp-0.1.0-cp38-cp38-linux_x86_64.whl
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from webp) (1.14.4)
# Requirement already satisfied: Pillow>=4.0.0 in /opt/conda/lib/python3.8/site-packages (from webp) (8.1.0)
# Requirement already satisfied: numpy>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from webp) (1.19.5)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.8/site-packages (from cffi>=1.0.0->webp) (2.20)
# Installing collected packages: webp
# Successfully installed webp-0.1.0
# Found existing installation: Pillow 8.1.0
# Uninstalling Pillow-8.1.0:
#   Successfully uninstalled Pillow-8.1.0
# Collecting Pillow
#   Using cached Pillow-8.1.0-cp38-cp38-manylinux1_x86_64.whl (2.2 MB)
# Installing collected packages: Pillow
# Successfully installed Pillow-8.1.0
# Collecting piexif
#   Using cached piexif-1.1.3-py2.py3-none-any.whl (20 kB)
# Installing collected packages: piexif
# Successfully installed piexif-1.1.3
