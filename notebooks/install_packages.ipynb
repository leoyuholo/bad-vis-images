# %%
# !apt update && apt install -y libmagic-dev libxrender1 libxtst6 libxi6
# !pip install altair vega_datasets
# !pip install ffmpy
# !pip install ImageHash
# !pip install imgur-downloader
# !pip install imutils
# !pip install opencv-python
# !pip install pafy
# !pip install praw
# !pip install pydash
# !pip install pymongo
# !pip install python-magic
# !pip install pytumblr
# !pip install requests-cache
# !pip install requests_toolbelt
# !pip install simplejson
# !pip install termcolor
# !pip install tweepy
# !pip install youtube-dl
# !python3 -m pip install pyppeteer

# sequence dependent
# !pip install webp
# !pip uninstall -y Pillow
# !pip install Pillow
# !pip install piexif
# Out:
# Collecting altair
#   Using cached altair-4.1.0-py3-none-any.whl (727 kB)
# Collecting vega_datasets
#   Using cached vega_datasets-0.8.0-py2.py3-none-any.whl (210 kB)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from altair) (2.11.2)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.8/site-packages (from altair) (3.2.0)
# Requirement already satisfied: pandas>=0.18 in /opt/conda/lib/python3.8/site-packages (from altair) (1.1.0)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.8/site-packages (from altair) (0.3)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from altair) (1.19.1)
# Requirement already satisfied: toolz in /opt/conda/lib/python3.8/site-packages (from altair) (0.10.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from jinja2->altair) (1.1.1)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema->altair) (0.16.0)
# Requirement already satisfied: six>=1.11.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema->altair) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.8/site-packages (from jsonschema->altair) (19.3.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from jsonschema->altair) (49.2.1.post20200802)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.18->altair) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.18->altair) (2020.1)
# Installing collected packages: altair, vega-datasets
# Successfully installed altair-4.1.0 vega-datasets-0.8.0
# Processing /home/jovyan/.cache/pip/wheels/89/ba/63/44887ceb692de6586cf0788c901dace9b3a371e914a9b4ad79/ffmpy-0.2.3-py3-none-any.whl
# Installing collected packages: ffmpy
# Successfully installed ffmpy-0.2.3
# Processing /home/jovyan/.cache/pip/wheels/cc/57/bb/6f9f52a6d8187b8f806210e3378837aa4dc6219cd64cb99846/ImageHash-4.1.0-py2.py3-none-any.whl
# Requirement already satisfied: pillow in /opt/conda/lib/python3.8/site-packages (from ImageHash) (7.2.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from ImageHash) (1.15.0)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.8/site-packages (from ImageHash) (1.5.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.8/site-packages (from ImageHash) (1.19.1)
# Requirement already satisfied: PyWavelets in /opt/conda/lib/python3.8/site-packages (from ImageHash) (1.1.1)
# Installing collected packages: ImageHash
# Successfully installed ImageHash-4.1.0
# Processing /home/jovyan/.cache/pip/wheels/fd/69/78/57c931209ddd1d90d8e55745d3b2dce118e2ad514337a744cd/imgur_downloader-0.2.2-py3-none-any.whl
# Requirement already satisfied: click in /opt/conda/lib/python3.8/site-packages (from imgur-downloader) (7.1.2)
# Installing collected packages: imgur-downloader
# Successfully installed imgur-downloader-0.2.2
# Processing /home/jovyan/.cache/pip/wheels/c8/d6/0f/b0c3892b70c59f0d202f8619a449f7d14cb839a0af2f943869/imutils-0.5.3-py3-none-any.whl
# Installing collected packages: imutils
# Successfully installed imutils-0.5.3
# Collecting opencv-python
#   Using cached opencv_python-4.3.0.36-cp38-cp38-manylinux2014_x86_64.whl (43.7 MB)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.8/site-packages (from opencv-python) (1.19.1)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.3.0.36
# Collecting pafy
#   Using cached pafy-0.5.5-py2.py3-none-any.whl (35 kB)
# Installing collected packages: pafy
# Successfully installed pafy-0.5.5
# Collecting praw
#   Using cached praw-7.1.0-py3-none-any.whl (152 kB)
# Collecting prawcore<2.0,>=1.3.0
#   Downloading prawcore-1.5.0-py3-none-any.whl (15 kB)
# Collecting websocket-client>=0.54.0
#   Using cached websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting update-checker>=0.17
#   Downloading update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: requests<3.0,>=2.6.0 in /opt/conda/lib/python3.8/site-packages (from prawcore<2.0,>=1.3.0->praw) (2.24.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from websocket-client>=0.54.0->praw) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3.0,>=2.6.0->prawcore<2.0,>=1.3.0->praw) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0,>=2.6.0->prawcore<2.0,>=1.3.0->praw) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3.0,>=2.6.0->prawcore<2.0,>=1.3.0->praw) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests<3.0,>=2.6.0->prawcore<2.0,>=1.3.0->praw) (3.0.4)
# Installing collected packages: prawcore, websocket-client, update-checker, praw
# Successfully installed praw-7.1.0 prawcore-1.5.0 update-checker-0.18.0 websocket-client-0.57.0
# Collecting pydash
#   Using cached pydash-4.8.0-py2.py3-none-any.whl (84 kB)
# Installing collected packages: pydash
# Successfully installed pydash-4.8.0
# Collecting pymongo
#   Using cached pymongo-3.11.0-cp38-cp38-manylinux2014_x86_64.whl (530 kB)
# Installing collected packages: pymongo
# Successfully installed pymongo-3.11.0
# Collecting python-magic
#   Using cached python_magic-0.4.18-py2.py3-none-any.whl (8.6 kB)
# Installing collected packages: python-magic
# Successfully installed python-magic-0.4.18
# Collecting pytumblr
#   Using cached PyTumblr-0.1.0-py2.py3-none-any.whl (15 kB)
# Processing /home/jovyan/.cache/pip/wheels/8e/70/28/3d6ccd6e315f65f245da085482a2e1c7d14b90b30f239e2cf4/future-0.18.2-py3-none-any.whl
# Collecting requests-oauthlib
#   Using cached requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from requests-oauthlib->pytumblr) (3.0.1)
# Requirement already satisfied: requests>=2.0.0 in /opt/conda/lib/python3.8/site-packages (from requests-oauthlib->pytumblr) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib->pytumblr) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib->pytumblr) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib->pytumblr) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=2.0.0->requests-oauthlib->pytumblr) (2020.6.20)
# Installing collected packages: future, requests-oauthlib, pytumblr
# Successfully installed future-0.18.2 pytumblr-0.1.0 requests-oauthlib-1.3.0
# Collecting requests-cache
#   Using cached requests_cache-0.5.2-py2.py3-none-any.whl (22 kB)
# Requirement already satisfied: requests>=1.1.0 in /opt/conda/lib/python3.8/site-packages (from requests-cache) (2.24.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests>=1.1.0->requests-cache) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests>=1.1.0->requests-cache) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests>=1.1.0->requests-cache) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests>=1.1.0->requests-cache) (2.10)
# Installing collected packages: requests-cache
# Successfully installed requests-cache-0.5.2
# Collecting requests_toolbelt
#   Using cached requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
# Requirement already satisfied: requests<3.0.0,>=2.0.1 in /opt/conda/lib/python3.8/site-packages (from requests_toolbelt) (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.1->requests_toolbelt) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.1->requests_toolbelt) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.1->requests_toolbelt) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.0.1->requests_toolbelt) (2.10)
# Installing collected packages: requests-toolbelt
# Successfully installed requests-toolbelt-0.9.1
# Collecting simplejson
#   Using cached simplejson-3.17.2-cp38-cp38-manylinux2010_x86_64.whl (137 kB)
# Installing collected packages: simplejson
# Successfully installed simplejson-3.17.2
# Processing /home/jovyan/.cache/pip/wheels/a0/16/9c/5473df82468f958445479c59e784896fa24f4a5fc024b0f501/termcolor-1.1.0-py3-none-any.whl
# Installing collected packages: termcolor
# Successfully installed termcolor-1.1.0
# Collecting tweepy
#   Using cached tweepy-3.9.0-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.8/site-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /opt/conda/lib/python3.8/site-packages (from tweepy) (2.24.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.8/site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (1.25.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /opt/conda/lib/python3.8/site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.1)
# Installing collected packages: tweepy
# Successfully installed tweepy-3.9.0
# Collecting youtube-dl
#   Using cached youtube_dl-2020.7.28-py2.py3-none-any.whl (1.8 MB)
# Installing collected packages: youtube-dl
# Successfully installed youtube-dl-2020.7.28
# Collecting pyppeteer
#   Using cached pyppeteer-0.2.2-py3-none-any.whl (145 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /opt/conda/lib/python3.8/site-packages (from pyppeteer) (4.48.2)
# Collecting websockets<9.0,>=8.1
#   Using cached websockets-8.1-cp38-cp38-manylinux2010_x86_64.whl (78 kB)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /opt/conda/lib/python3.8/site-packages (from pyppeteer) (1.25.10)
# Collecting pyee<8.0.0,>=7.0.1
#   Using cached pyee-7.0.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /opt/conda/lib/python3.8/site-packages (from pyppeteer) (1.4.4)
# Installing collected packages: websockets, pyee, pyppeteer
# Successfully installed pyee-7.0.2 pyppeteer-0.2.2 websockets-8.1
# Processing /home/jovyan/.cache/pip/wheels/f5/ea/92/8d98d79a5f24a9c8f841747c7300d66510b74a09dc2f41766c/webp-0.1.0a16-cp38-cp38-linux_x86_64.whl
# Requirement already satisfied: Pillow>=4.0.0 in /opt/conda/lib/python3.8/site-packages (from webp) (7.2.0)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from webp) (1.14.1)
# Requirement already satisfied: numpy>=1.0.0 in /opt/conda/lib/python3.8/site-packages (from webp) (1.19.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.8/site-packages (from cffi>=1.0.0->webp) (2.20)
# Installing collected packages: webp
# Successfully installed webp-0.1.0a16
# Found existing installation: Pillow 7.2.0
# Uninstalling Pillow-7.2.0:
#   Successfully uninstalled Pillow-7.2.0
# Collecting Pillow
#   Using cached Pillow-7.2.0-cp38-cp38-manylinux1_x86_64.whl (2.2 MB)
# Installing collected packages: Pillow
# Successfully installed Pillow-7.2.0
# Collecting piexif
#   Using cached piexif-1.1.3-py2.py3-none-any.whl (20 kB)
# Installing collected packages: piexif
# Successfully installed piexif-1.1.3
